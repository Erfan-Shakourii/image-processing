# %% [markdown]
# # Finding Countours

# %% [markdown]
# contours, hierarchy = cv2.findContours(image, mode, method)

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('images/shapes.png', 0)
ret, thresh = cv2.threshold(image, 127, 255, 0)
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

for contour in contours:
    print(contour.shape)
# Out:
# (24, 1, 2)
# (134, 1, 2)
# (146, 1, 2)
# (17, 1, 2)
# (117, 1, 2)
# (4, 1, 2)

# %%
bgr_image = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)
cv2.polylines(bgr_image, [contours[0]], True, (250,0,0), 6)
cv2.polylines(bgr_image, [contours[1]], True, (0,250,0), 6)
cv2.polylines(bgr_image, [contours[3]], True, (0,0,250), 6)
cv2.polylines(bgr_image, [contours[-1]], True, (100,0,0), 6)
plt.imshow(bgr_image[...,::-1])

# %% [markdown]
# ## drawContours

# %%
image = cv2.imread('images/shapes.png', 0)
ret, thresh = cv2.threshold(image, 127, 255, 0)
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
bgr_image = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)
#Draw All contours
all_contours = cv2.drawContours(bgr_image, contours, -1, (0,200,200),3)
# Draw Specific contour
#all_contours = cv2.drawContours(bgr_image, contours, 3, (0,200,200),3)

plt.imshow(all_contours)

# %% [markdown]
# ## Contour Approximation Method

# %%
image = cv2.imread('images/rectangle.png', 0)
ret, thresh = cv2.threshold(image, 127, 255, 0)
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

# %%
image = cv2.imread('images/rectangle.png', 0)
ret, thresh = cv2.threshold(image, 127, 255, 0)
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

print("cv2.CHAIN_APPROX_NONE:")
print("contours[0].shape: {} so number of points for the contour: {}".format(contours[0].shape, len(contours[0])))

bgr_image = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)
for point in contours[0]:
    cv2.circle(bgr_image, (point[0][0], point[0][1]), 2, (255,100,0), -1)
plt.imshow(bgr_image[...,::-1]); plt.title('CHAIN_APPROX_NONE')
print('-'*5)


contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
print("cv2.CHAIN_APPROX_SIMPLE:")
print("contours[0].shape: {} so number of points for the contour: {}".format(contours[0].shape, len(contours[0])))

bgr_image = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)
for point in contours[0]:
    cv2.circle(bgr_image, (point[0][0], point[0][1]), 2, (255,100,0), -1)
    
plt.figure(); plt.imshow(bgr_image[...,::-1]); plt.title('CHAIN_APPROX_SIMPLE')
# Out:
# cv2.CHAIN_APPROX_NONE:
# contours[0].shape: (482, 1, 2) so number of points for the contour: 482
# -----
# cv2.CHAIN_APPROX_SIMPLE:
# contours[0].shape: (7, 1, 2) so number of points for the contour: 7
# Text(0.5, 1.0, 'CHAIN_APPROX_SIMPLE')

# %% [markdown]
# https://docs.opencv.org/4.x/d4/d73/tutorial_py_contours_begin.html
